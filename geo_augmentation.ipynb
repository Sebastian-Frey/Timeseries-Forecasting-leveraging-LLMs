# %% [markdown]
# # Geographical Augmentation with Country Matcher
#
# This notebook reads the parquet data and enriches it with geographical information using the country_matcher module.

# %%
import sys
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# Add the 6_Method3 directory to the path to import country_matcher
sys.path.insert(0, '6_Method3')

from country_matcher import extract_place_struct, add_location_columns

print("✓ Modules imported successfully")
# Out:
# ✓ Modules imported successfully

# %% [markdown]
# ## Load Parquet Data

# %%
# Read the parquet data
data_path = 'data/domain_sem_dtw.parquet'
df = pd.read_parquet(data_path)

print(f"✓ Data loaded: {df.shape[0]:,} rows × {df.shape[1]} columns")
print(f"\nColumns: {list(df.columns)}")
print(f"\nFirst few rows:")
df.head()
# Out:
# ✓ Data loaded: 199,272 rows × 66 columns
#
# Columns: ['week', 'domain', 'keyword', 'impressions_sum', 'adcost_sum', 'adclicks_sum', 'cpc_week', 'avg_sim_top25_this_week', 'avg_sim_top25_last_week', 'n_sim_this_week', 'n_sim_last_week', 'dom_share_avis', 'dom_share_avisautonoleggio', 'dom_share_aviscarsales', 'dom_share_budget', 'dom_share_dollar', 'dom_share_economybookings', 'dom_share_hertz', 'dom_share_letsdrive', 'dom_share_sixt', 'dom_share_thrifty', 'n_dev_desktop', 'n_dev_mobile', 'n_dev_tablet', 'n_st_branded_search', 'n_st_generic_search', 'semantic_neighbour_1', 'semantic_neighbour_2', 'semantic_neighbour_3', 'semantic_neighbour_4', 'semantic_neighbour_5', 'semantic_neighbour_6', 'semantic_neighbour_7', 'semantic_neighbour_8', 'semantic_neighbour_9', 'semantic_neighbour_10', 'semantic_neighbour_11', 'semantic_neighbour_12', 'semantic_neighbour_13', 'semantic_neighbour_14', 'semantic_neighbour_15', 'semantic_neighbour_16', 'semantic_neighbour_17', 'semantic_neighbour_18', 'semantic_neighbour_19', 'semantic_neighbour_20', 'dtw_neighbour_1', 'dtw_neighbour_2', 'dtw_neighbour_3', 'dtw_neighbour_4', 'dtw_neighbour_5', 'dtw_neighbour_6', 'dtw_neighbour_7', 'dtw_neighbour_8', 'dtw_neighbour_9', 'dtw_neighbour_10', 'dtw_neighbour_11', 'dtw_neighbour_12', 'dtw_neighbour_13', 'dtw_neighbour_14', 'dtw_neighbour_15', 'dtw_neighbour_16', 'dtw_neighbour_17', 'dtw_neighbour_18', 'dtw_neighbour_19', 'dtw_neighbour_20']
#
# First few rows:
#       week domain                       keyword  impressions_sum  adcost_sum  \
# 0  01-2021   avis                  3 month hire              5.0    3.399534
# 1  01-2021   avis         airport aberdeen hire              4.0    8.208105
# 2  01-2021   avis    airport avis hire aberdeen              4.0    7.243941
# 3  01-2021   avis  airport avis hire birmingham              2.0    7.904708
# 4  01-2021   avis     airport avis hire glasgow              4.0   21.599380
#
#    adclicks_sum  cpc_week  avg_sim_top25_this_week  avg_sim_top25_last_week  \
# 0           6.0  0.566589                 0.308505                 0.310740
# 1           4.0  2.052026                 0.390090                 0.381570
# 2           4.0  1.810985                 0.451481                 0.449888
# 3           2.0  3.952354                 0.465347                 0.466825
# 4           4.0  5.399845                 0.472526                 0.472557
#
#    n_sim_this_week  ...  dtw_neighbour_11  dtw_neighbour_12  dtw_neighbour_13  \
# 0            33357  ...               NaN               NaN          0.123609
# 1             4320  ...          1.993423          1.221523               NaN
# 2            11694  ...          0.627048          1.945000               NaN
# 3            11946  ...               NaN               NaN               NaN
# 4            11773  ...          0.627048               NaN          3.224821
#
#    dtw_neighbour_14  dtw_neighbour_15  dtw_neighbour_16  dtw_neighbour_17  \
# 0               NaN          1.360000          0.032864               NaN
# 1               NaN          0.501413               NaN          0.819382
# 2          1.020000               NaN          0.109937               NaN
# 3          2.335852               NaN          2.570000               NaN
# 4               NaN          0.898229          0.618734          0.982104
#
#    dtw_neighbour_18  dtw_neighbour_19  dtw_neighbour_20
# 0               NaN          0.717773          0.024648
# 1               NaN          0.560363               NaN
# 2          0.171214               NaN          0.390887
# 3          2.342857          0.971538               NaN
# 4               NaN          0.439748               NaN
#
# [5 rows x 66 columns]

# %%
# Check data info
print("Data Info:")
print(df.info())
print(f"\n{'='*50}\n")
print("Data description:")
print(df.describe())
# Out:
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199272 entries, 0 to 199271
# Data columns (total 66 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   week                        199272 non-null  object
#  1   domain                      199272 non-null  object
#  2   keyword                     199272 non-null  object
#  3   impressions_sum             199272 non-null  float64
#  4   adcost_sum                  199272 non-null  float64
#  5   adclicks_sum                199272 non-null  float64
#  6   cpc_week                    199272 non-null  float64
#  7   avg_sim_top25_this_week     199272 non-null  float64
#  8   avg_sim_top25_last_week     198257 non-null  float64
#  9   n_sim_this_week             199272 non-null  int64
#  10  n_sim_last_week             199272 non-null  int64
#  11  dom_share_avis              199272 non-null  float64
#  12  dom_share_avisautonoleggio  199272 non-null  float64
#  13  dom_share_aviscarsales      199272 non-null  float64
#  14  dom_share_budget            199272 non-null  float64
#  15  dom_share_dollar            199272 non-null  float64
#  16  dom_share_economybookings   199272 non-null  float64
#  17  dom_share_hertz             199272 non-null  float64
#  18  dom_share_letsdrive         199272 non-null  float64
#  19  dom_share_sixt              199272 non-null  float64
#  20  dom_share_thrifty           199272 non-null  float64
#  21  n_dev_desktop               199272 non-null  uint32
#  22  n_dev_mobile                199272 non-null  uint32
#  23  n_dev_tablet                199272 non-null  uint32
#  24  n_st_branded_search         199272 non-null  uint32
#  25  n_st_generic_search         199272 non-null  uint32
#  26  semantic_neighbour_1        192325 non-null  float64
#  27  semantic_neighbour_2        192050 non-null  float64
#  28  semantic_neighbour_3        191626 non-null  float64
#  29  semantic_neighbour_4        191204 non-null  float64
#  30  semantic_neighbour_5        191123 non-null  float64
#  31  semantic_neighbour_6        190824 non-null  float64
#  32  semantic_neighbour_7        190713 non-null  float64
#  33  semantic_neighbour_8        191048 non-null  float64
#  34  semantic_neighbour_9        190531 non-null  float64
#  35  semantic_neighbour_10       190766 non-null  float64
#  36  semantic_neighbour_11       191019 non-null  float64
#  37  semantic_neighbour_12       190784 non-null  float64
#  38  semantic_neighbour_13       190661 non-null  float64
#  39  semantic_neighbour_14       190580 non-null  float64
#  40  semantic_neighbour_15       190714 non-null  float64
#  41  semantic_neighbour_16       190604 non-null  float64
#  42  semantic_neighbour_17       190570 non-null  float64
#  43  semantic_neighbour_18       190624 non-null  float64
#  44  semantic_neighbour_19       190504 non-null  float64
#  45  semantic_neighbour_20       190772 non-null  float64
#  46  dtw_neighbour_1             192467 non-null  float64
#  47  dtw_neighbour_2             192449 non-null  float64
#  48  dtw_neighbour_3             191973 non-null  float64
#  49  dtw_neighbour_4             192229 non-null  float64
#  50  dtw_neighbour_5             192174 non-null  float64
#  51  dtw_neighbour_6             192098 non-null  float64
#  52  dtw_neighbour_7             191931 non-null  float64
#  53  dtw_neighbour_8             192073 non-null  float64
#  54  dtw_neighbour_9             191962 non-null  float64
#  55  dtw_neighbour_10            192110 non-null  float64
#  56  dtw_neighbour_11            191789 non-null  float64
#  57  dtw_neighbour_12            191759 non-null  float64
#  58  dtw_neighbour_13            191775 non-null  float64
#  59  dtw_neighbour_14            191837 non-null  float64
#  60  dtw_neighbour_15            191899 non-null  float64
#  61  dtw_neighbour_16            192142 non-null  float64
#  62  dtw_neighbour_17            191768 non-null  float64
#  63  dtw_neighbour_18            191697 non-null  float64
#  64  dtw_neighbour_19            191797 non-null  float64
#  65  dtw_neighbour_20            191967 non-null  float64
# dtypes: float64(56), int64(2), object(3), uint32(5)
# memory usage: 96.5+ MB
# None
#
# ==================================================
#
# Data description:
#        impressions_sum     adcost_sum   adclicks_sum       cpc_week  \
# count    199272.000000  199272.000000  199272.000000  199272.000000
# mean       1120.158095     448.140609     356.046800       2.800198
# std       13976.870840    6539.284923    5923.771926       2.687563
# min           1.000000       0.008214       1.000000       0.008214
# 25%          12.000000      10.630000       6.000000       1.133701
# 50%          42.000000      32.766807      14.000000       2.076388
# 75%         174.000000      99.975816      42.000000       3.541311
# max      636456.000000  443218.447863  297542.000000      77.349996
#
#        avg_sim_top25_this_week  avg_sim_top25_last_week  n_sim_this_week  \
# count            199272.000000            198257.000000    199272.000000
# mean                  0.587828                 0.587820     26625.943208
# std                   0.086274                 0.086352     15647.976716
# min                   0.201366                 0.201366      1421.000000
# 25%                   0.560357                 0.560341     13036.000000
# 50%                   0.605514                 0.605499     23058.500000
# 75%                   0.640605                 0.640647     38068.000000
# max                   0.806402                 0.806402     88528.000000
#
#        n_sim_last_week  dom_share_avis  dom_share_avisautonoleggio  ...  \
# count    199272.000000   199272.000000               199272.000000  ...
# mean      26599.580016        0.115410                    0.000592  ...
# std       15704.956103        0.007366                    0.000171  ...
# min           0.000000        0.085953                    0.000000  ...
# 25%       13060.000000        0.114724                    0.000615  ...
# 50%       23124.500000        0.117719                    0.000621  ...
# 75%       38071.000000        0.119033                    0.000641  ...
# max       88528.000000        0.128686                    0.000985  ...
#
#        dtw_neighbour_11  dtw_neighbour_12  dtw_neighbour_13  dtw_neighbour_14  \
# count     191789.000000     191759.000000     191775.000000     191837.000000
# mean           3.194828          3.210825          3.174260          3.222202
# std            2.976721          3.033801          2.920531          3.042921
# min            0.008274          0.008214          0.008274          0.008214
# 25%            1.271366          1.264741          1.287401          1.306726
# 50%            2.406160          2.384162          2.400868          2.413019
# 75%            4.135703          4.135637          4.100330          4.128519
# max           77.349996         77.349996         77.349996         77.349996
#
#        dtw_neighbour_15  dtw_neighbour_16  dtw_neighbour_17  dtw_neighbour_18  \
# count     191899.000000     192142.000000     191768.000000     191697.000000
# mean           3.137621          3.196809          3.214489          3.259127
# std            2.936817          2.886255          3.004819          3.037183
# min            0.008214          0.008274          0.008214          0.008214
# 25%            1.255556          1.288148          1.279065          1.310000
# 50%            2.345487          2.432168          2.403182          2.430368
# 75%            4.067378          4.159288          4.155593          4.207304
# max           77.349996         52.862135         63.691226         77.349996
#
#        dtw_neighbour_19  dtw_neighbour_20
# count     191797.000000     191967.000000
# mean           3.264065          3.166516
# std            3.057932          2.711681
# min            0.008361          0.008214
# 25%            1.281518          1.341825
# 50%            2.464603          2.476046
# 75%            4.222028          4.136607
# max           77.349996         77.349996
#
# [8 rows x 63 columns]

# %% [markdown]
# ## Test Location Extraction on Sample Keywords
#
# First, let's test the location extraction on a few sample keywords from the data.

# %%
# Check if there's a keyword column and get unique keywords
if 'keyword' in df.columns:
    unique_keywords = df['keyword'].unique()
    sample_keywords = unique_keywords[:10]
    print(f"Total unique keywords: {len(unique_keywords):,}")
    print(f"\nSample keywords to test:")
    for i, kw in enumerate(sample_keywords, 1):
        print(f"{i}. {kw}")
else:
    print("Available columns:", list(df.columns))
    print("\nNote: Looking for a 'keyword' column. You may need to rename a column.")
# Out:
# Total unique keywords: 1,519
#
# Sample keywords to test:
# 1. 3 month hire
# 2. airport aberdeen hire
# 3. airport avis hire aberdeen
# 4. airport avis hire birmingham
# 5. airport avis hire glasgow
# 6. airport avis hire manchester
# 7. airport avis hire newcastle
# 8. airport edinburgh hire
# 9. airport hire
# 10. airport hire aberdeen

# %%
# Test location extraction on sample keywords
if 'keyword' in df.columns:
    print("Testing location extraction on sample keywords:\n")
    print(f"{'Keyword':<50} {'City':<20} {'Country':<25} {'Continent':<20}")
    print("="*115)
    
    for kw in sample_keywords:
        result = extract_place_struct(str(kw))
        city = result['detected_city'] or '-'
        country = result['detected_country']
        continent = result['detected_continent']
        print(f"{str(kw)[:48]:<50} {city:<20} {country:<25} {continent:<20}")
# Out:
# Testing location extraction on sample keywords:
#
# Keyword                                            City                 Country                   Continent
# ===================================================================================================================
# 3 month hire                                       -                    Global                    Global
# airport aberdeen hire                              Aberdeen             United Kingdom            Europe
# airport avis hire aberdeen                         Aberdeen             United Kingdom            Europe
# airport avis hire birmingham                       Birmingham           United Kingdom            Europe
# airport avis hire glasgow                          Glasgow              United Kingdom            Europe
# airport avis hire manchester                       Manchester           United Kingdom            Europe
# airport avis hire newcastle                        Newcastle            Australia                 Oceania
# airport edinburgh hire                             Edinburgh            United Kingdom            Europe
# airport hire                                       -                    Global                    Global
# airport hire aberdeen                              Aberdeen             United Kingdom            Europe

# %% [markdown]
# ## Enrich Full Dataset with Geographical Information
#
# Now let's enrich the entire dataset by adding geographical columns.

# %%
# Progress tracking function
def progress_tracker(current, total):
    percentage = (current / total) * 100
    if current % 100 == 0 or current == total:  # Print every 100 keywords
        print(f"Progress: {current:,}/{total:,} keywords ({percentage:.1f}%)")

# Enrich the dataset with geographical information
if 'keyword' in df.columns:
    print(f"Enriching {len(df['keyword'].unique()):,} unique keywords with geographical data...\n")
    
    df_enriched = add_location_columns(
        df,
        keywords=df['keyword'].unique().tolist(),
        progress_callback=progress_tracker,
        batch_size=100
    )
    
    print("\n✓ Enrichment complete!")
    print(f"\nNew columns added: detected_city, detected_country, detected_continent")
    print(f"Enriched data shape: {df_enriched.shape}")
else:
    print("Cannot proceed: 'keyword' column not found in dataframe")
# Out:
# Enriching 1,519 unique keywords with geographical data...
#
# Progress: 100/1,519 keywords (6.6%)
# Progress: 200/1,519 keywords (13.2%)
# Progress: 300/1,519 keywords (19.7%)
# Progress: 400/1,519 keywords (26.3%)
# Progress: 500/1,519 keywords (32.9%)
# Progress: 600/1,519 keywords (39.5%)
# Progress: 700/1,519 keywords (46.1%)
# Progress: 800/1,519 keywords (52.7%)
# Progress: 900/1,519 keywords (59.2%)
# Progress: 1,000/1,519 keywords (65.8%)
# Progress: 1,100/1,519 keywords (72.4%)
# Progress: 1,200/1,519 keywords (79.0%)
# Progress: 1,300/1,519 keywords (85.6%)
# Progress: 1,400/1,519 keywords (92.2%)
# Progress: 1,500/1,519 keywords (98.7%)
# Progress: 1,519/1,519 keywords (100.0%)
#
# ✓ Enrichment complete!
#
# New columns added: detected_city, detected_country, detected_continent
# Enriched data shape: (199272, 69)

# %% [markdown]
# ## Analyze Enriched Data

# %%
# Display sample of enriched data
if 'keyword' in df.columns:
    print("Sample of enriched data:")
    display_cols = ['keyword', 'detected_city', 'detected_country', 'detected_continent']
    display_cols = [col for col in display_cols if col in df_enriched.columns]
    df_enriched[display_cols].head(20)
# Out:
# Sample of enriched data:

# %%
# Geographical distribution statistics
if 'keyword' in df.columns and 'detected_continent' in df_enriched.columns:
    print("GEOGRAPHICAL DISTRIBUTION\n")
    
    print("By Continent:")
    print(df_enriched['detected_continent'].value_counts())
    
    print("\n" + "="*60 + "\n")
    
    print("Top 20 Countries:")
    print(df_enriched['detected_country'].value_counts().head(20))
    
    print("\n" + "="*60 + "\n")
    
    print("Top 20 Cities (with detected cities):")
    print(df_enriched[df_enriched['detected_city'].notna()]['detected_city'].value_counts().head(20))
# Out:
# GEOGRAPHICAL DISTRIBUTION
#
# By Continent:
# detected_continent
# North America    76556
# Global           68753
# Europe           35373
# Africa            7978
# Oceania           7110
# Asia              2532
# South America      970
# Name: count, dtype: int64
#
# ============================================================
#
# Top 20 Countries:
# detected_country
# United States           69286
# Global                  68753
# United Kingdom          13924
# Mali                     6455
# Australia                5856
# Italy                    4854
# Canada                   4527
# France                   3097
# Germany                  2291
# Spain                    2148
# Portugal                 1605
# Austria                  1433
# South Africa             1273
# New Zealand              1254
# United Arab Emirates     1107
# Croatia                   831
# Mexico                    818
# Cuba                      723
# Philippines               593
# Netherlands               478
# Name: count, dtype: int64
#
# ============================================================
#
# Top 20 Cities (with detected cities):
# detected_city
# San                6455
# Orlando            5818
# Miami              5627
# Las Vegas          5132
# Tampa              3618
# Fort Lauderdale    3512
# Phoenix            3156
# Denver             3071
# Los Angeles        2875
# Atlanta            2792
# Glasgow            2370
# Seattle            2172
# Chicago            2062
# Dallas             2044
# Edinburgh          1908
# Fort Myers         1539
# Houston            1445
# London             1411
# Philadelphia       1343
# West Palm Beach    1333
# Name: count, dtype: int64

# %%
# Coverage statistics
if 'keyword' in df.columns and 'detected_city' in df_enriched.columns:
    total_keywords = len(df_enriched['keyword'].unique())
    with_city = df_enriched[df_enriched['detected_city'].notna()]['keyword'].nunique()
    with_country = df_enriched[df_enriched['detected_country'] != 'Global']['keyword'].nunique()
    
    print("COVERAGE STATISTICS\n")
    print(f"Total unique keywords: {total_keywords:,}")
    print(f"Keywords with detected city: {with_city:,} ({with_city/total_keywords*100:.1f}%)")
    print(f"Keywords with detected country: {with_country:,} ({with_country/total_keywords*100:.1f}%)")
    print(f"Keywords without geographical info: {total_keywords - with_country:,} ({(total_keywords-with_country)/total_keywords*100:.1f}%)")
# Out:
# COVERAGE STATISTICS
#
# Total unique keywords: 1,519
# Keywords with detected city: 923 (60.8%)
# Keywords with detected country: 1,005 (66.2%)
# Keywords without geographical info: 514 (33.8%)

# %% [markdown]
# ## Example Filters and Queries

# %%
# Example filters and queries
if 'keyword' in df.columns and 'detected_country' in df_enriched.columns:
    print("EXAMPLE 1: Keywords from United States")
    us_keywords = df_enriched[df_enriched['detected_country'] == 'United States']['keyword'].unique()
    print(f"Found {len(us_keywords):,} unique US keywords")
    print("Sample:", us_keywords[:10].tolist())
    
    print("\n" + "="*60 + "\n")
    
    print("EXAMPLE 2: Keywords from Europe")
    europe_keywords = df_enriched[df_enriched['detected_continent'] == 'Europe']['keyword'].unique()
    print(f"Found {len(europe_keywords):,} unique European keywords")
    print("Sample:", europe_keywords[:10].tolist())
    
    print("\n" + "="*60 + "\n")
    
    print("EXAMPLE 3: Keywords with specific cities")
    city_data = df_enriched[df_enriched['detected_city'].notna()][['keyword', 'detected_city', 'detected_country']].drop_duplicates()
    print(f"Found {len(city_data):,} keywords with city information")
    print("\nSample:")
    print(city_data.head(15))
# Out:
# EXAMPLE 1: Keywords from United States
# Found 517 unique US keywords
# Sample: ['airport hire geneva', 'avis rent near me', 'avis rentals near me', 'car rental avis chicago', 'car rental avis denver', 'car rental avis las vegas', 'car rental avis memphis tn', 'car rental avis miami', 'car rental avis near me', 'car rental avis orlando']
#
# ============================================================
#
# EXAMPLE 2: Keywords from Europe
# Found 276 unique European keywords
# Sample: ['airport aberdeen hire', 'airport avis hire aberdeen', 'airport avis hire birmingham', 'airport avis hire glasgow', 'airport avis hire manchester', 'airport edinburgh hire', 'airport hire aberdeen', 'airport hire birmingham', 'airport hire edinburgh', 'airport hire glasgow']
#
# ============================================================
#
# EXAMPLE 3: Keywords with specific cities
# Found 923 keywords with city information
#
# Sample:
#                          keyword detected_city detected_country
# 1          airport aberdeen hire      Aberdeen   United Kingdom
# 2     airport avis hire aberdeen      Aberdeen   United Kingdom
# 3   airport avis hire birmingham    Birmingham   United Kingdom
# 4      airport avis hire glasgow       Glasgow   United Kingdom
# 5   airport avis hire manchester    Manchester   United Kingdom
# 6    airport avis hire newcastle     Newcastle        Australia
# 7         airport edinburgh hire     Edinburgh   United Kingdom
# 9          airport hire aberdeen      Aberdeen   United Kingdom
# 10       airport hire birmingham    Birmingham   United Kingdom
# 11        airport hire edinburgh     Edinburgh   United Kingdom
# 13           airport hire geneva        Geneva    United States
# 14          airport hire glasgow       Glasgow   United Kingdom
# 15        airport hire newcastle     Newcastle        Australia
# 16        airport newcastle hire     Newcastle        Australia
# 18             avis hire cardiff       Cardiff   United Kingdom

# %% [markdown]
# ## Save Enriched Data

# %%
# Save the enriched data
if 'keyword' in df.columns:
    output_path = 'data/domain_sem_geo_enriched.parquet'
    df_enriched.to_parquet(output_path, index=False)
    print(f"✓ Enriched data saved to: {output_path}")
    print(f"  Shape: {df_enriched.shape}")
    print(f"  Columns: {list(df_enriched.columns)}")
# Out:
# ✓ Enriched data saved to: data/domain_sem_geo_enriched.parquet
#   Shape: (199272, 69)
#   Columns: ['week', 'domain', 'keyword', 'impressions_sum', 'adcost_sum', 'adclicks_sum', 'cpc_week', 'avg_sim_top25_this_week', 'avg_sim_top25_last_week', 'n_sim_this_week', 'n_sim_last_week', 'dom_share_avis', 'dom_share_avisautonoleggio', 'dom_share_aviscarsales', 'dom_share_budget', 'dom_share_dollar', 'dom_share_economybookings', 'dom_share_hertz', 'dom_share_letsdrive', 'dom_share_sixt', 'dom_share_thrifty', 'n_dev_desktop', 'n_dev_mobile', 'n_dev_tablet', 'n_st_branded_search', 'n_st_generic_search', 'semantic_neighbour_1', 'semantic_neighbour_2', 'semantic_neighbour_3', 'semantic_neighbour_4', 'semantic_neighbour_5', 'semantic_neighbour_6', 'semantic_neighbour_7', 'semantic_neighbour_8', 'semantic_neighbour_9', 'semantic_neighbour_10', 'semantic_neighbour_11', 'semantic_neighbour_12', 'semantic_neighbour_13', 'semantic_neighbour_14', 'semantic_neighbour_15', 'semantic_neighbour_16', 'semantic_neighbour_17', 'semantic_neighbour_18', 'semantic_neighbour_19', 'semantic_neighbour_20', 'dtw_neighbour_1', 'dtw_neighbour_2', 'dtw_neighbour_3', 'dtw_neighbour_4', 'dtw_neighbour_5', 'dtw_neighbour_6', 'dtw_neighbour_7', 'dtw_neighbour_8', 'dtw_neighbour_9', 'dtw_neighbour_10', 'dtw_neighbour_11', 'dtw_neighbour_12', 'dtw_neighbour_13', 'dtw_neighbour_14', 'dtw_neighbour_15', 'dtw_neighbour_16', 'dtw_neighbour_17', 'dtw_neighbour_18', 'dtw_neighbour_19', 'dtw_neighbour_20', 'detected_city', 'detected_country', 'detected_continent']
